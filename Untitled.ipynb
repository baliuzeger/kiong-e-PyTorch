# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
df = pd.read_csv('capital_bike_share/data/202012-capitalbikeshare-tripdata.csv')

# %%
df
# Out:
#                  ride_id rideable_type           started_at  \
# 0       C04E20007D039277   docked_bike  2020-12-02 09:10:36
# 1       A488C0D9F4761D06  classic_bike  2020-12-31 12:46:29
# 2       9E7E97A927A85552  classic_bike  2020-12-31 12:47:03
# 3       565C5C331ABAD77B  classic_bike  2020-12-29 13:50:51
# 4       7576B3F4B4D6ADFF  classic_bike  2020-12-27 12:30:28
# ...                  ...           ...                  ...
# 105824  A10ED3D50E5AB612   docked_bike  2020-12-12 13:49:55
# 105825  F146CC9669ABF5EC   docked_bike  2020-12-03 13:43:26
# 105826  614005BC98FE93F7   docked_bike  2020-12-06 07:27:47
# 105827  86783BF38F4567FA   docked_bike  2020-12-21 13:46:01
# 105828  A7F61D67643CB526  classic_bike  2020-12-18 09:09:48
#
#                    ended_at  \
# 0       2020-12-02 09:24:12
# 1       2020-12-31 14:01:07
# 2       2020-12-31 14:01:04
# 3       2020-12-29 14:12:22
# 4       2020-12-27 12:36:12
# ...                     ...
# 105824  2020-12-12 14:17:02
# ...

# %%
df_2012Q4 = pd.read_csv('/Users/balisun/projects/kionge/capital_bike_share/data/2012/2012Q4-capitalbikeshare-tripdata.csv')

# %%
df_2012Q4
# Out:
#         Duration           Start date             End date  \
# 0            611  2012-10-01 00:02:06  2012-10-01 00:12:17
# 1            612  2012-10-01 00:02:52  2012-10-01 00:13:05
# 2            734  2012-10-01 00:06:34  2012-10-01 00:18:48
# 3            219  2012-10-01 00:07:27  2012-10-01 00:11:06
# 4            924  2012-10-01 00:07:28  2012-10-01 00:22:53
# ...          ...                  ...                  ...
# 470840      8630  2012-12-31 23:51:38  2013-01-01 02:15:29
# 470841       418  2012-12-31 23:56:19  2013-01-01 00:03:17
# 470842       384  2012-12-31 23:56:35  2013-01-01 00:03:00
# 470843       448  2012-12-31 23:58:20  2013-01-01 00:05:49
# 470844       251  2012-12-31 23:59:23  2013-01-01 00:03:34
#
#         Start station number  \
# 0                      31230
# 1                      31624
# 2                      31234
# 3                      31106
# 4                      31109
# ...                      ...
# 470840                 31619
# ...

# %%
df_2011 = pd.read_csv('/Users/balisun/projects/kionge/capital_bike_share/data/2011/2011-capitalbikeshare-tripdata.csv')

# %%
df_2011
# Out:
#          Duration           Start date             End date  \
# 0            3548  2011-01-01 00:01:29  2011-01-01 01:00:37
# 1             346  2011-01-01 00:02:46  2011-01-01 00:08:32
# 2             562  2011-01-01 00:06:13  2011-01-01 00:15:36
# 3             434  2011-01-01 00:09:21  2011-01-01 00:16:36
# 4             233  2011-01-01 00:28:26  2011-01-01 00:32:19
# ...           ...                  ...                  ...
# 1226762       300  2011-12-31 23:41:19  2011-12-31 23:46:20
# 1226763       387  2011-12-31 23:46:43  2011-12-31 23:53:10
# 1226764       261  2011-12-31 23:47:27  2011-12-31 23:51:49
# 1226765      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
# 1226766       468  2011-12-31 23:55:56  2012-01-01 00:03:45
#
#          Start station number                      Start station  \
# 0                       31620                      5th & F St NW
# 1                       31105               14th & Harvard St NW
# ...

# %%
df_book = pd.read_csv('/Users/balisun/projects/kionge/capital_bike_share/data/from_book/hour.csv')

# %%
df_book
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df_book.plot(x='dteday',y=['cnt'],
             figsize=(15,5),
             xlim=(0,24*31),
             c=df_book['workingday'].map({'0':'green','1':'blue'}))#.map({'0':'green','1':'blue'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/dev-pkgs/miniconda3/envs/PyMooHong/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/dev-pkgs/miniconda3/envs/PyMooHong/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
df_book.plot(x='dteday',y=['workingday','holiday'],figsize=(15,5),xlim=(0,24*31))

# %%
def scatterplot(df, x_dim, y_dim, x_size, y_size, category, xmin, xmax):
    x = df[x_dim]
    y = df[y_dim]
    fig, ax = plt.subplots(figsize=(x_size, y_size))
    
    #defining an array of colors  
    colors = ['#2300A8', '#00A658']  #assigns a color to each data point
    ax.scatter(x, y, alpha=0.70, c= df[category], cmap=cm.brg)
    ax.set_xlim(left=xmin, right=xmax)
  
    #adds a title and axes labels
    #ax.set_title('Distance vs Workout Duration')
    # ax.set_xlabel('Distance (Km)')
    # ax.set_ylabel('Workout Duration (min)')
  
    #removing top and right borders
    # ax.spines['top'].set_visible(False)
    # ax.spines['right'].set_visible(False)#adds major gridlines
    # ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)plt.show()

    plt.show()

# %%
scatterplot(df_book, 'instant', 'cnt', 15, 5, 'workingday', 0, 24*15)

# %%
scatterplot(df_book, 'dteday', 'cnt', 15, 5, 'workingday', 0, 15)

# %%
#我们取出最后一列的前50条记录来进行预测
counts = df_book['cnt'][:50]

#获得变量x，它是1，2，……，50
x = np.arange(len(counts))

# 将counts转成预测变量（标签）：y
y = np.array(counts)

# 绘制一个图形，展示曲线长的样子
plt.figure(figsize = (10, 7)) #设定绘图窗口大小
plt.plot(x, y, 'o-') # 绘制原始数据
plt.xlabel('X') #更改坐标轴标注
plt.ylabel('Y') #更改坐标轴标注
plt.show()
